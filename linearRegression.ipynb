# %% [markdown]
# # Linear Regression

# %%
# Import Libraries

import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Load Dataset

melb_housing_df = pd.read_csv("./datasets/melb_housing_data.csv")
melb_housing_df.head(5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
# 21 features in total
fig, axis = plt.subplots(7, 3, figsize=(15,6))

for a, feature in enumerate(melb_housing_df.columns):
    row = int(a/3)
    col = a%3
    ax = axis[row][col]
    ax.scatter(melb_housing_df[feature], melb_housing_df["Price"])
    # ax.set_title(f'{feature} against Price')
    # axis[current_axis[0], current_axis[1]].plot(melbourne_housing_dataset["Price"], melbourne_housing_dataset[feature])
plt.tight_layout()
plt.show()

# %%
# add filter that filters out column that has too many unique values
# check for outliers after columns have been filtered
x = [x if x < 15000 else 0 for x in melb_housing_df["Landsize"]]
# print(len(x.unique()))
# print(len(melb_housing_df))
y = melb_housing_df["Price"]
plt.scatter(x, y)
